# %%
direction_lst = direction_lst_5
def Convert(string):
    list1 = []
    list1[:0] = string
    return list1
key = 4

direction_lst_1 = Convert("""""")
direction_lst_2 = Convert("...")
direction_lst_3 = Convert("...")
direction_lst_4 = Convert('...')
direction_lst_5 =Convert('...')



class Key:
    def __init__(self, num):
        self.num = num
    
    def Move(self, lst, direction):
        ind = lst.index(self.num)
        
        if direction == "L":    
            key = Key(lst[ind-1])
        elif direction == "R":
            key = Key(lst[ind+1])
        elif direction =="U":
            key = Key(lst[ind+2])
        else:
            key = Key(lst[ind+3])
    
        return self.num, key.num
        

key_1.Move(test_lst,"U")

key_1 = Key(1)
key_2 = Key(2)
key_3 = Key(3)
key_4 = Key(4)
key_5 = Key(5)
key_6 = Key(6)
key_7 = Key(7)
key_8 = Key(8)
key_9 = Key(9)

def direction(lst):
    current = lst.pop(0)
    return current


def make_lst (key):
    if key == 1:
        lst = [0,1,2,0,4]##left, self, right, up, down
    elif key ==2:
        lst = [1,2,3,0,5]
    elif key ==3:
        lst = [2,3,0,0,6]
    elif key == 4:
        lst =[0,4,5,1,7]
    elif key == 5:
        lst = [4,5,6,2,8]
    elif key == 6:
        lst = [5,6,0,3,9]
    elif key ==7:
        lst =[0,7,8,4,0]
    elif key == 8:
        lst =[7,8,9,5,0]
    else:
        lst =[8,9,0,6,0]
    return lst


while direction_lst and key!= 0:
    for i in range (len(direction_lst)):
        current_direction = direction(direction_lst)
        lst = make_lst(key)
        key = Key(key)
        print(f"key = {key.num},lst = {lst}, current direction = {current_direction}") 
        move_output = key.Move(lst,current_direction)
        
        
        key = move_output[1]
        print(f"key = {key}")
        if key == 0:
            answer = move_output[0]
            key = answer
            print(key)
# Out:
# key = 4,lst = [0, 4, 5, 1, 7], current direction = L
# key = 0
# 4
# key = 4,lst = [0, 4, 5, 1, 7], current direction = D
# key = 7
# key = 7,lst = [0, 7, 8, 4, 0], current direction = U
# key = 4
# key = 4,lst = [0, 4, 5, 1, 7], current direction = D
# key = 7
# key = 7,lst = [0, 7, 8, 4, 0], current direction = R
# key = 8
# key = 8,lst = [7, 8, 9, 5, 0], current direction = R
# key = 9
# key = 9,lst = [8, 9, 0, 6, 0], current direction = D
# key = 0
# 9
# key = 9,lst = [8, 9, 0, 6, 0], current direction = L
# key = 8
# key = 8,lst = [7, 8, 9, 5, 0], current direction = U
# key = 5
# key = 5,lst = [4, 5, 6, 2, 8], current direction = U
# key = 2
# key = 2,lst = [1, 2, 3, 0, 5], current direction = D
# key = 5
# key = 5,lst = [4, 5, 6, 2, 8], current direction = D
# key = 8
# key = 8,lst = [7, 8, 9, 5, 0], current direction = R
# key = 9
# key = 9,lst = [8, 9, 0, 6, 0], current direction = L
# key = 8
# key = 8,lst = [7, 8, 9, 5, 0], current direction = L
# key = 7
# ...

# %%
class AbstractKey:
    def __init__(self, num):
        self.num = num
    
    def right(self):
        pass
    def left(self):
        pass
    def up(self):
        pass
    def down(self):
        pass

class Key(AbstractKey):
    def __init__()
# Out:
#   Input In [1]
#     class Key(AbstractKey)
#                           ^
# SyntaxError: invalid syntax
